# %%
import pandas as pd
import requests
import pandas_datareader.data as web
import datetime

# %%
url = "http://sentiment-app.pjj2rgg23c.us-east-1.elasticbeanstalk.com/test/SPY/20180101/20190531"
request = requests.get(url)
request_json = request.json()
df_sent = pd.DataFrame(request_json['sentiment'],request_json['dates'],
                       columns=['sentiment'])
df_sent.head()
# Out:
#             sentiment
# 2018-01-01       0.05
# 2018-01-02       0.05
# 2018-01-03       0.07
# 2018-01-04       0.09
# 2018-01-05       0.06

# %%
df_sent.plot();

# %%
request_json['dates']
# Out:
# ['2018-01-01',
#  '2018-01-02',
#  '2018-01-03',
#  '2018-01-04',
#  '2018-01-05',
#  '2018-01-06',
#  '2018-01-07',
#  '2018-01-08',
#  '2018-01-09',
#  '2018-01-10',
#  '2018-01-11',
#  '2018-01-12',
#  '2018-01-13',
#  '2018-01-14',
#  '2018-01-15',
#  '2018-01-16',
#  '2018-01-17',
#  '2018-01-18',
#  '2018-01-19',
#  '2018-01-20',
#  '2018-01-21',
#  '2018-01-22',
#  '2018-01-23',
#  '2018-01-24',
#  '2018-01-25',
#  '2018-01-26',
#  '2018-01-27',
#  '2018-01-28',
#  '2018-01-29',
#  '2018-01-30',
#  '2018-01-31',
#  '2018-02-01',
#  '2018-02-02',
#  '2018-02-03',
#  '2018-02-04',
#  '2018-02-05',
#  '2018-02-06',
#  '2018-02-07',
#  '2018-02-08',
#  '2018-02-09',
#  '2018-02-10',
#  '2018-02-11',
#  '2018-02-12',
#  '2018-02-13',
#  '2018-02-14',
#  '2018-02-15',
#  '2018-02-16',
#  '2018-02-17',
#  '2018-02-18',
#  '2018-02-19',
#  '2018-02-20',
#  '2018-02-21',
#  '2018-02-22',
#  '2018-02-23',
#  '2018-02-24',
#  '2018-02-25',
#  '2018-02-26',
#  '2018-02-27',
# ...

# %%
tic = 'AMD'

# %%
f"http://sentiment-app.pjj2rgg23c.us-east-1.elasticbeanstalk.com/test/{tic}/20180101/20190531"
# Out:
# 'http://sentiment-app.pjj2rgg23c.us-east-1.elasticbeanstalk.com/test/AMD/20180101/20190531'
